# %% [markdown]
# <a href="https://www.kaggle.com/code/borilion/ml-zoomcamp-1?scriptVersionId=143324925" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Question 1
# > What's the version of Pandas that you installed?
#
# You can get the version information using the __version__ field:

# %%
pd.__version__

# %% [markdown]
# Question 2
# > How many columns are in the dataset?

# %%
url = "https://raw.githubusercontent.com/alexeygrigorev/datasets/master/housing.csv"
df = pd.read_csv(url)
len(df)

# %%
df.head()

# %% [markdown]
# Question 3
# > Which columns in the dataset have missing values?

# %%
missing_values = df.isna().sum()
columns_with_missing_values = missing_values[missing_values > 0]
print(columns_with_missing_values)

# %% [markdown]
# Question 4
# > How many unique values does the ocean_proximity column have?

# %%
unique_values = df['ocean_proximity'].nunique()
print("Number of unique values in 'ocean_proximity' column:", unique_values)

# %% [markdown]
# Question 5
# > What's the average value of the median_house_value for the houses located near the bay?

# %%
near_bay_houses = df[df['ocean_proximity'] == 'NEAR BAY']
average_median_house_value_near_bay = near_bay_houses['median_house_value'].mean()
print("Average median_house_value for houses near the bay:", average_median_house_value_near_bay)

# %% [markdown]
# Question 6
# 1. Calculate the average of total_bedrooms column in the dataset.
# 2. Use the fillna method to fill the missing values in total_bedrooms with the mean value from the previous step.
# 3. Now, calculate the average of total_bedrooms again.
# 4. Has it changed?

# %%
initial_average = df['total_bedrooms'].mean()
df['total_bedrooms'].fillna(initial_average, inplace=True)
average_after_fillna = df['total_bedrooms'].mean()
if round(initial_average, 3) != round(average_after_fillna, 3):
    print("Yes")
else:
    print("No")

# %% [markdown]
# Question 7
# 1. Select all the options located on islands.
# 2. Select only columns housing_median_age, total_rooms, total_bedrooms.
# 3. Get the underlying NumPy array. Let's call it X.
# 4. Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
# 5. Compute the inverse of XTX.
# 6. Create an array y with values [950, 1300, 800, 1000, 1300].
# 7. Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
# 8. What's the value of the last element of w?

# %%
island_rows = df[df['ocean_proximity'] == 'ISLAND']
selected_columns = island_rows[['housing_median_age', 'total_rooms', 'total_bedrooms']]
X = selected_columns.to_numpy()
XTX = np.dot(X.T, X)
inv_XTX = np.linalg.inv(XTX)
y = np.array([950, 1300, 800, 1000, 1300])
w = np.dot(np.dot(inv_XTX, X.T), y)
last_element_w = w[-1]

print("The value of the last element of w:", last_element_w)
